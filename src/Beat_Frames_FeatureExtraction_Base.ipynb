# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### **IMPORTING LIBRARY AND SETTING PATH**

# %%
# Needed Libraries
import numpy as np
from scipy import signal as sig
from Signal_Analysis_Class import heart_rate
import wfdb as wf
import pywt as WT
import matplotlib.pyplot as plt
import os
from multiprocessing.pool import Pool
from pydmd import DMD
import warnings



# Specify the default path
os.chdir('..')
dir = os.getcwd()

# Global variables
results = []

# %% [markdown]
# ### **FUNCTION DEFINITIONS**

# %%
def Signal_Filter(Signal):
    # Wavelet Tranformation
    Coeff = WT.wavedec(Signal, 'db3', level = 11)
    Coeff_Mod = []

    for i in range(0,11):
        if i > 3:
            Coeff_Mod.append(Coeff[i])
        else:
            Coeff_Mod.append(np.zeros(Coeff[i].shape))

    # Inverse Wavelet Transform
    Signal_WT = WT.waverec(Coeff_Mod, 'db3')

    # Notch Filter
    samp_freq = 1000
    notch_freq = 60.0
    quality_factor = 2

    b_notch, a_notch = sig.iirnotch(notch_freq, quality_factor, samp_freq)
    Signal_Notch =  sig.filtfilt(b_notch, a_notch, Signal_WT)

    # Fourth order Butterworth low pass filter at 100Hz
    sos = sig.butter(N = 4, Wn = 100,output ='sos', fs=1000)
    return sig.sosfilt(sos, Signal_Notch)

def Patient_Signals_Filter(Signals_Array):
    Signals_Filtered_Array = None

    for s in Signals_Array:
        Signal_Filtered = Signal_Filter(s)

        if str(type(Signals_Filtered_Array)) == "<class 'NoneType'>":
            Signals_Filtered_Array = Signal_Filtered
        else:
            Signals_Filtered_Array = np.vstack((Signals_Filtered_Array,Signal_Filtered))

    return Signals_Filtered_Array

def Beat_ind(Signal_Filterd_Array):

    Peak_ind = None

    for s in Signal_Filterd_Array:

        hr = heart_rate(s,1000)
        result = np.array(hr.find_r_peaks())

        result = np.unique(result[result > 0])
        result = result[1:len(result)-1]

        for i in range(1,len(result)-1):
            if result[i] > 300:
                valid_peaks = [result[i]]
                break

        for i in range(1,len(result)-1):
            if result[i] - valid_peaks[-1] > 250:
                valid_peaks.append(result[i])
        
        valid_peaks = np.array(valid_peaks)
        result = valid_peaks

        if str(type(Peak_ind)) == "<class 'NoneType'>":
                Peak_ind = np.array([result])
        else:
            if Peak_ind.shape[1] == result.shape[0]:
                Peak_ind = np.vstack((Peak_ind,result))
            elif Peak_ind.shape[1] > result.shape[0]:
                Peak_ind = np.vstack((Peak_ind[:,:result.shape[0]],result))
            elif Peak_ind.shape[1] < result.shape[0]:
                Peak_ind = np.vstack((Peak_ind,result[:Peak_ind.shape[1]]))
            else:
                print("Indexing error!!!")
                break
    
    return Peak_ind

def Beat_Signal_Extraction(Ori_signal, ind):

    Sample_Signal = None
    for n in range(12):
        if str(type(Sample_Signal)) == "<class 'NoneType'>":
            Sample_Signal = Ori_signal[n,int(ind[n]-250):int(ind[n]+400)]
        else:
            Sample_Signal = np.vstack((Sample_Signal,Ori_signal[n,int(ind[n]-250):int(ind[n]+400)]))
    return Sample_Signal

def Arg_X(Sample_signal):
    
    B = Sample_signal.flatten(order = 'F')
    N = (Sample_signal.shape[1] - 109) + 1

    Arg_Matrix = None

    for n in range(N):
        V = B[n*12:n*12 + 109*12]
        if str(type(Arg_Matrix)) == "<class 'NoneType'>":
            Arg_Matrix = V
        else:
            Arg_Matrix = np.vstack((Arg_Matrix,V))
    
    return Arg_Matrix.T

def FeatureExtraction_Beat(Signal_F, ind,n):

    A = Beat_Signal_Extraction(Signal_F, ind)
    B = Arg_X(A)

    X_DMD =  DMD(svd_rank = 0, exact= True)
    X_DMD.fit(B)

    Lambda = X_DMD.eigs
    Modes = X_DMD.modes    

    M = int(Modes.shape[0]/12)

    Modes_restacked = np.zeros((12,Modes.shape[1]))

    for j in range(M):
        Modes_restacked = Modes_restacked + Modes[int(j*12):int(j*12 + 12),:]

    Modes_restacked = Modes_restacked/M

    Lambda_ind_u = np.where(np.abs(Lambda) > 1)
    Lambda_ind_s = np.where(np.abs(Lambda) < 1)

    Lambda_u = Lambda[Lambda_ind_u]
    Lambda_s = Lambda[Lambda_ind_s]

    Pho_u = Modes_restacked[:,Lambda_ind_u].reshape((12,Lambda_u.shape[0]))
    Pho_s = Modes_restacked[:,Lambda_ind_s].reshape((12,Lambda_s.shape[0]))

    C = Lambda_s.shape[0]
    D = Lambda_u.shape[0]

    R_N = D/(C+D)
    R_Lambda = np.sum(np.abs(Lambda_u))/(np.sum(np.abs(Lambda_u)) + np.sum(np.abs(Lambda_s)))

    Lam_min = np.min(np.abs(Lambda_s), initial = -1 )
    Lam_max = np.max(np.abs(Lambda_u), initial = -1 )

    R_M = np.sum(np.sum(np.abs(Pho_u), axis = 1))/(np.sum(np.sum(np.abs(Pho_u), axis = 1)) + np.sum(np.sum(np.abs(Pho_s), axis = 1)))
    R_P = np.sum(np.sum(np.angle(Pho_u), axis = 1))#/(np.sum(np.sum(np.angle(Pho_u), axis = 1)) +  np.sum(np.sum(np.angle(Pho_s), axis = 1)))
    

    M_s = np.sum(np.abs(Pho_s), axis=1)/C
    P_s = np.sum(np.angle(Pho_s), axis=1)/C

    M_u = np.sum(np.abs(Pho_u), axis=1)/D
    P_u = np.sum(np.angle(Pho_u), axis=1)/D

    print(f"n: {n}, Stable: {C}, Unstable: {D}")
    Feature_String = str(R_N) + "," + str(R_Lambda) + "," + str(Lam_min) + "," + str(Lam_max) + "," + str(R_M) + "," + str(R_P) + Numpy_arr_to_String(M_s) + Numpy_arr_to_String(P_s) + Numpy_arr_to_String(M_u) + Numpy_arr_to_String(P_u)
    return (str(n) + ',' + Feature_String)

def Numpy_arr_to_String(Arr):
    string = ''
    for no in Arr:
        string = string + ',' + str(no) 

    return string

def get_results(result):
    global results
    results.append(result)

def Patient_FeatureExtraction_Beat(patient, name):
    Signal_Array, fields = wf.rdsamp( dir + '/DATASET/' + patient + '/' + name)

    Signal_Array = Signal_Array.T
    Signal_Array = Signal_Array[:12,:]

    Signal_Filterd_Array = Patient_Signals_Filter(Signal_Array)

    Beat_index = Beat_ind(Signal_Filterd_Array)

    Peaks_count = Beat_index.shape[1]

    Result_File = []
    print(f"Patient: {patient} Audio ID: {name}")
    for n in range(Peaks_count):
        Result_File.append(patient + '_' + FeatureExtraction_Beat(Signal_Filterd_Array,Beat_index[:,n],n))
        
    return(Result_File)

# %%
def Patient_FeatureExtraction_Frame(patient, name):
    Signal_Array, fields = wf.rdsamp( dir + '/DATASET/' + patient + '/' + name)

    Signal_Array = Signal_Array.T
    Signal_Array = Signal_Array[:12,:]


    Signal_Filterd_Array = Patient_Signals_Filter(Signal_Array)
    Frame_count = int(Signal_Filterd_Array.shape[1]/4096)

    Result_File = []

    warnings.simplefilter("ignore", UserWarning)
    print(f"Patient: {patient} Audio ID: {name}")
    for n in range(Frame_count):
        if Signal_Filterd_Array[:,int(n*4096):int((n+1)*4096)].shape[1] == 4096:
            Result_File.append( patient + '_' + FeatureExtraction_Frame(Signal_Filterd_Array[:,int(n*4096):int((n+1)*4096)],n))
        else:
            break
        
    return(Result_File)

def FeatureExtraction_Frame(Signal_F, n):

    #A = Signal_F[:,int(n*4096):int((n+1)*4096)]
    #print(A.shape)
    B = Arg_X(Signal_F)

    X_DMD =  DMD(svd_rank = 100)
    X_DMD.fit(B)

    Lambda = X_DMD.eigs
    Modes = X_DMD.modes    
    
    M = int(Modes.shape[0]/12)

    Modes_restacked = np.zeros((12,Modes.shape[1]))

    for j in range(M):
        Modes_restacked = Modes_restacked + Modes[int(j*12):int(j*12 + 12),:]

    Modes_restacked = Modes_restacked/M

    Lambda_ind_u = np.where(np.abs(Lambda) > 1)
    Lambda_ind_s = np.where(np.abs(Lambda) < 1)

    Lambda_u = Lambda[Lambda_ind_u]
    Lambda_s = Lambda[Lambda_ind_s]

    Pho_u = Modes_restacked[:,Lambda_ind_u].reshape((12,Lambda_u.shape[0]))
    Pho_s = Modes_restacked[:,Lambda_ind_s].reshape((12,Lambda_s.shape[0]))

    C = Lambda_s.shape[0]
    D = Lambda_u.shape[0]

    R_N = D/(C+D)
    R_Lambda = np.sum(np.abs(Lambda_u))/(np.sum(np.abs(Lambda_u)) + np.sum(np.abs(Lambda_s)))

    Lam_min = np.min(np.abs(Lambda_s),initial = -1 )
    Lam_max = np.max(np.abs(Lambda_u), initial = -1 )

    R_M = np.sum(np.sum(np.abs(Pho_u), axis = 1))/(np.sum(np.sum(np.abs(Pho_u), axis = 1)) + np.sum(np.sum(np.abs(Pho_s), axis = 1)))
    R_P = np.sum(np.sum(np.angle(Pho_u), axis = 1))/(np.sum(np.sum(np.angle(Pho_u), axis = 1)) +  np.sum(np.sum(np.angle(Pho_s), axis = 1)))
    

    M_s = np.sum(np.abs(Pho_s), axis=1)/C
    P_s = np.sum(np.angle(Pho_s), axis=1)/C

    M_u = np.sum(np.abs(Pho_u), axis=1)/D
    P_u = np.sum(np.angle(Pho_u), axis=1)/D

    print(f"n: {n}, Stable: {C}, Unstable: {D}")
    Feature_String = str(R_N) + "," + str(R_Lambda) + "," + str(Lam_min) + "," + str(Lam_max) + "," + str(R_M) + "," + str(R_P) + Numpy_arr_to_String(M_s) + Numpy_arr_to_String(P_s) + Numpy_arr_to_String(M_u) + Numpy_arr_to_String(P_u)
    return (str(n) + ',' + Feature_String)

# %% [markdown]
# ### **LOADING DATASET**

# %%
# Specifying Dataset Directory
os.chdir(dir + '/DATASET')
Patients_List = os.listdir()
os.chdir(dir)

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]  
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    print(fields['comments'][4])


# Healthy control List
HC = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]  
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Healthy control' in fields['comments'][4]:
        HC.append([patient,F[0].replace('.dat','')])

# Myocardial infarction
MI = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]  
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Myocardial infarction' in fields['comments'][4]:
        MI.append([patient,F[0].replace('.dat','')])

# Cardiomyopathy/Heart failure
HF = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]  
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Cardiomyopathy' in fields['comments'][4] or 'Heart failure' in fields['comments'][4]:
        HF.append([patient,F[0].replace('.dat','')])

# Bundle branch block
BBB = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]  
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Bundle branch block' in fields['comments'][4]:
        BBB.append([patient,F[0].replace('.dat','')])

# Dysrhythmia
DA = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Dysrhythmia' in fields['comments'][4]:
        DA.append([patient,F[0].replace('.dat','')])

# Myocardial hypertrophy
MH = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Myocardial hypertrophy' in fields['comments'][4]:
        MH.append([patient,F[0].replace('.dat','')])

# Valvular heart disease
VH = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Valvular heart' in fields['comments'][4]:
        VH.append([patient,F[0].replace('.dat','')])

# Myocarditis
MC = []

for patient in Patients_List:
    os.chdir(dir + '/DATASET/' + patient) 
    Files = os.listdir() 
    F = [a for a in Files if a.endswith('.dat')]
    _, fields = wf.rdsamp( dir + '/DATASET/' + patient +'/' + F[0].replace('.dat',''))
    if 'Myocarditis' in fields['comments'][4]:
        MC.append([patient,F[0].replace('.dat','')])
# Out:
# Reason for admission: Heart failure (NYHA 2)
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Valvular heart disease
# Reason for admission: Healthy control
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Hypertrophy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Heart failure (NYHA 3)
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: n/a
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Unstable angina
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Valvular heart disease
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Valvular heart disease
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Hypertrophy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocarditis
# Reason for admission: Bundle branch block
# Reason for admission: n/a
# Reason for admission: Healthy control
# Reason for admission: Hypertrophy
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Healthy control
# Reason for admission: Hypertrophy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Stable angina
# Reason for admission: Dysrhythmia
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Dysrhythmia
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Hypertrophy
# Reason for admission: Dysrhythmia
# Reason for admission: n/a
# Reason for admission: Myocarditis
# Reason for admission: Cardiomyopathy
# Reason for admission: Heart failure (NYHA 4)
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Dysrhythmia
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Palpitation
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Valvular heart disease
# Reason for admission: Cardiomyopathy
# Reason for admission: Valvular heart disease
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocarditis
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Hypertrophy
# Reason for admission: Dysrhythmia
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Hypertrophy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Stable angina
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: Myocarditis
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Cardiomyopathy
# Reason for admission: n/a
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Cardiomyopathy
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Bundle branch block
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Healthy control
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Bundle branch block
# Reason for admission: Healthy control
# Reason for admission: Healthy control
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Healthy control
# Reason for admission: Cardiomyopathy
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: n/a
# Reason for admission: Myocardial infarction
# Reason for admission: Myocardial infarction
# Reason for admission: Valvular heart disease
# Reason for admission: Healthy control

# %% [markdown]
# ### **SEGEMENTATION**

# %% [markdown]
# #### **BEAT WISE** - **Myocarditis**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = MC

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open("/home/senume/Project/MIS/mis-ECG_analysis_DMD/FEATURE_EXTRACTION/BEAT/Features_Beat_Myocarditis.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Valvular heart disease**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = VH

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open("/home/senume/Project/MIS/mis-ECG_analysis_DMD/FEATURE_EXTRACTION/BEAT/Features_Beat_Valvular heart disease.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Myocardial hypertrophy**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = MH

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Features_Beat_Myocardial hypertrophy.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Dysrhythmia**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = DA

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Features_Beat_Dysrhythmia.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Bundle branch block**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = BBB

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Bundle branch block.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Cardiomyopathy/Heart failure**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = HF

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Cardiomyopathy_Heart failure.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **BEAT WISE** - **Myocardial infarction**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = MI[:15]
print(len(Z))

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Myocardial infarction.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()
# Out:
# 15

# %% [markdown]
# #### **BEAT WISE** - **Health Control**

# %%
Z = HC[:15]
print(len(Z))

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Beat, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/BEAT/Health Control.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()
# Out:
# 15

# %% [markdown]
# #### **FRAME WISE** - **Myocarditis**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = MC

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Myocarditis.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Valvular heart disease**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = VH

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Valvular heart disease.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Myocardial hypertrophy**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = MH

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Myocardial hypertrophy.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Dysrhythmia**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = DA

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FEATURE_EXTRACTION/FRAME/Features_Frame_Dysrhythmia.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Bundle branch block**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = BBB

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FEATURE_EXTRACTION/FRAME/Features_Frame_Bundle branch block.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Cardiomyopathy/Heart failure**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)

Z = HF

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Cardiomyopathy_Heart failure.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()

# %% [markdown]
# #### **FRAME WISE** - **Myocardial infarction**

# %%
warnings.simplefilter("ignore", RuntimeWarning)
warnings.simplefilter("ignore", UserWarning)
Z = MI
print(len(Z))

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Myocardial infarction.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()
# Out:
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient282 Audio ID: s0539_re
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient261 Audio ID: s0497_re
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient145 Audio ID: s0201_re
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient022 Audio ID: s0074lre
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient287 Audio ID: s0547_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient265 Audio ID: s0501_re
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient205 Audio ID: s0426_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient003 Audio ID: s0017lre
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient097 Audio ID: s0384lre
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient268 Audio ID: s0505_re
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient057 Audio ID: s0198lre
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# Patient: patient052 Audio ID: s0190lre
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient020 Audio ID: s0069lre
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient101 Audio ID: s0410lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient008 Audio ID: s0028lre
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 94, Unstable: 6
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient140 Audio ID: s0019_re
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient032 Audio ID: s0165lre
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 82, Unstable: 18
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient037 Audio ID: s0120lre
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient015 Audio ID: s0047lre
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0n: 3, Stable: 100, Unstable: 0
#
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 98, Unstable: 2
# n: 5, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# Patient: patient100 Audio ID: s0401lre
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient084 Audio ID: s0289lre
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient030 Audio ID: s0117lre
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient091 Audio ID: s0357lre
# n: 11, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient283 Audio ID: s0542_re
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient062 Audio ID: s0212lre
# n: 3, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient042 Audio ID: s0347lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient111 Audio ID: s0203_re
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 7, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient195 Audio ID: s0337lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient096 Audio ID: s0379lre
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# Patient: patient293 Audio ID: s0557_re
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient082 Audio ID: s0267lre
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient004 Audio ID: s0020bre
# n: 0, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 88, Unstable: 12
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient189 Audio ID: s0309lre
# n: 9, Stable: 96, Unstable: 4
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient072 Audio ID: s0240lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient029 Audio ID: s0098lre
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 3, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 12, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient028 Audio ID: s0093lre
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 92, Unstable: 8
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 96, Unstable: 4
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# Patient: patient024 Audio ID: s0084lre
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 11, Stable: 98, Unstable: 2
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient034 Audio ID: s0123lre
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 98, Unstable: 2
# n: 6, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient012 Audio ID: s0043lre
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient099 Audio ID: s0397lre
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient005 Audio ID: s0021are
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient043 Audio ID: s0141lre
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient086 Audio ID: s0316lre
# n: 12, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient230 Audio ID: s0454_re
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient142 Audio ID: s0351lre
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient055 Audio ID: s0194lre
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient038 Audio ID: s0125lrePatient: patient033 Audio ID: s0113lre
#
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient021 Audio ID: s0097lre
# n: 11, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0n: 1, Stable: 100, Unstable: 0
#
# n: 3, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient076 Audio ID: s0247lre
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient045 Audio ID: s0147lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient080 Audio ID: s0260lre
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0n: 4, Stable: 100, Unstable: 0
#
# n: 0, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient148 Audio ID: s0335lre
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 11, Stable: 98, Unstable: 2
# n: 9, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 98, Unstable: 2
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 98, Unstable: 2
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient292 Audio ID: s0555_re
# n: 11, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient152 Audio ID: s0004_re
# n: 2, Stable: 98, Unstable: 2
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 8, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient007 Audio ID: s0078lre
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient291 Audio ID: s0554_re
# Patient: patient053 Audio ID: s0191lre
# n: 11, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient135 Audio ID: s0334lre
# n: 8, Stable: 100, Unstable: 0
# n: 3, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient039 Audio ID: s0164lre
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient078 Audio ID: s0317lre
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient026 Audio ID: s0088lre
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# Patient: patient010 Audio ID: s0036lre
# n: 10, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient120 Audio ID: s0331lre
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient102 Audio ID: s0416lre
# n: 3, Stable: 100, Unstable: 0
# Patient: patient054 Audio ID: s0218lre
# n: 6, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient056 Audio ID: s0196lre
# n: 3, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# Patient: patient040 Audio ID: s0131lre
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient018 Audio ID: s0054lre
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0n: 8, Stable: 100, Unstable: 0
#
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient128 Audio ID: s0182_re
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient051 Audio ID: s0213lre
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient211 Audio ID: s0433_re
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient044 Audio ID: s0159lre
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient108 Audio ID: s0013_re
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient009 Audio ID: s0035_re
# n: 13, Stable: 98, Unstable: 2
# Patient: patient259 Audio ID: s0495_re
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient083 Audio ID: s0286lre
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient066 Audio ID: s0280lre
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient092 Audio ID: s0362lre
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient059 Audio ID: s0208lre
# n: 1, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient068 Audio ID: s0228lre
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient048 Audio ID: s0277lre
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# Patient: patient002 Audio ID: s0015lre
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient017 Audio ID: s0063lre
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient027 Audio ID: s0151lre
# n: 3, Stable: 100, Unstable: 0
# Patient: patient025 Audio ID: s0091lre
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient016 Audio ID: s0052lre
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 98, Unstable: 2
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# Patient: patient035 Audio ID: s0124lre
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2n: 5, Stable: 100, Unstable: 0
#
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient138 Audio ID: s0005_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient023 Audio ID: s0085lre
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 8, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient074 Audio ID: s0239lre
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient094 Audio ID: s0376lre
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient089 Audio ID: s0359lre
# n: 2, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient077 Audio ID: s0285lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient098 Audio ID: s0386lre
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient047 Audio ID: s0160lre
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient036 Audio ID: s0126lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient073 Audio ID: s0243lre
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient070 Audio ID: s0235lre
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient011 Audio ID: s0039lre
# n: 0, Stable: 98, Unstable: 2
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient067 Audio ID: s0227lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient064 Audio ID: s0220lre
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 96, Unstable: 4
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 4, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient226 Audio ID: s0449_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient273 Audio ID: s0511_re
# ...
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 88, Unstable: 12
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient019 Audio ID: s0070lre
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 2, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 98, Unstable: 2
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# Patient: patient031 Audio ID: s0100lre
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient139 Audio ID: s0223_re
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient197 Audio ID: s0350lre
# n: 12, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# Patient: patient193 Audio ID: s0008_re
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient088 Audio ID: s0343lre
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient231 Audio ID: s0455_re
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# Patient: patient087 Audio ID: s0321lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient061 Audio ID: s0210lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient006 Audio ID: s0027lre
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 98, Unstable: 2
# Patient: patient290 Audio ID: s0553_re
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient069 Audio ID: s0284lre
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient081 Audio ID: s0264lre
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient141 Audio ID: s0307lre
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient183 Audio ID: s0175_re
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient270 Audio ID: s0507_re
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient014 Audio ID: s0056lre
# n: 8, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient065 Audio ID: s0221lre
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# Patient: patient158 Audio ID: s0295lre
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 98, Unstable: 2
# Patient: patient294 Audio ID: s0559_re
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient060 Audio ID: s0209lre
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient160 Audio ID: s0222_re
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient207 Audio ID: s0428_re
# n: 1, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient063 Audio ID: s0214lre
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient103 Audio ID: s0332lre
# n: 7, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 94, Unstable: 6
# n: 12, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient075 Audio ID: s0327lre
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 86, Unstable: 14
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient274 Audio ID: s0512_re
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0

# %% [markdown]
# #### **FRAME WISE** - **Health Control**

# %%
Z = HC
print(len(Z))

with Pool() as pool:
    # prepare arguments
    items = [(Z[i][0],Z[i][1]) for i in range(len(Z))]
    # issues tasks to process pool
    result = pool.starmap_async(Patient_FeatureExtraction_Frame, items)
    # iterate results
    for result in result.get():
        f = open(dir + "/FEATURE_EXTRACTION/FRAME/Features_Frame_Health Control.csv", "a")
        for line in result:
            f.write(line + '\n')
        f.close()

pool.close()
pool.join()
# Out:
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 98, Unstable: 2
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient284 Audio ID: s0551_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient104 Audio ID: s0306lre
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient105 Audio ID: s0303lre
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 96, Unstable: 4
# n: 13, Stable: 100, Unstable: 0
# Patient: patient214 Audio ID: s0436_re
# n: 13, Stable: 98, Unstable: 2
# n: 13, Stable: 100, Unstable: 0
# Patient: patient117 Audio ID: s0291lre
# Patient: patient131 Audio ID: s0273lre
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient184 Audio ID: s0363lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient237 Audio ID: s0465_re
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient180 Audio ID: s0545_re
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient245 Audio ID: s0474_re
# n: 12, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# Patient: patient185 Audio ID: s0336lre
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient277 Audio ID: s0527_re
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient155 Audio ID: s0301lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient150 Audio ID: s0287lre
# n: 13, Stable: 100, Unstable: 0
# Patient: patient242 Audio ID: s0471_re
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient247 Audio ID: s0479_re
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 98, Unstable: 2
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0n: 3, Stable: 100, Unstable: 0
#
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 98, Unstable: 2
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 98, Unstable: 2
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient279 Audio ID: s0533_re
# n: 13, Stable: 100, Unstable: 0
# Patient: patient243 Audio ID: s0472_re
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# Patient: patient236 Audio ID: s0463_re
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# Patient: patient264 Audio ID: s0500_re
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 0, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 1, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 2, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 3, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 4, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 5, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 6, Stable: 98, Unstable: 2
# n: 7, Stable: 100, Unstable: 0
# n: 6, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 7, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 8, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 9, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 10, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 11, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 12, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
# n: 13, Stable: 100, Unstable: 0
